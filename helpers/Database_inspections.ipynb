# %%
import pymongo
import os
#from pymongo import MongoClient
#client = MongoClient("mongodb://user:password@127.0.0.1:27017/admin")
c = pymongo.MongoClient(f'mongodb://{os.environ["MONGO_USER"]}:{os.environ["MONGO_PASSWORD"]}@127.0.0.1:27017/admin')

# %%
dbn = c['daq']
rdbn = c['run']

# %%
dbn.list_collection_names()
# Out:
# ['status_new',
#  'options',
#  'detector_control_new',
#  'control',
#  'control2',
#  'aggregate_status',
#  'control3',
#  'detector_control',
#  'status',
#  'dispatcher_queue',
#  'aggregate_status_new',
#  'log_new',
#  'log',
#  'control_new',
#  'dac_calibration',
#  'redax_benchmarks',
#  'runs',
#  'system_monitor',
#  'dac_values']

# %%
rdbn.list_collection_names()
# Out:
# ['runs_new', 'runs_gas', 'runs']

# %%
type(dbn['detector_control_new'])
# Out:
# pymongo.collection.Collection

# %%
# for doc in dbn['detector_control_new'].find_one():
#     print(doc)

# %% [markdown]
# Create collection

# %%
dbn.create_collection('detector_control_new')
# Out:
# Collection(Database(MongoClient(host=['127.0.0.1:27017'], document_class=dict, tz_aware=False, connect=True), 'daq'), 'detector_control_new')

# %%
for doc in dbn['control_new'].find():
    print(doc)
# Out:
# {'_id': ObjectId('616938455a68e7300fcfba40'), 'command': 'stop', 'user': 'dipede', 'detector': 'xams', 'mode': 'document_V1730_software_update', 'createdAt': datetime.datetime(2021, 10, 15, 8, 13, 57, 8000), 'host': ['xams-daq_reader_0'], 'acknowledged': {'xams-daq_reader_0': 0}}
# {'_id': ObjectId('616938c009f2ba335a6d4d96'), 'command': 'stop', 'user': 'dipede', 'detector': 'xams', 'mode': 'document_V1730_software_update', 'createdAt': datetime.datetime(2021, 10, 15, 8, 16, 0, 79000), 'host': ['xams-daq_reader_0'], 'acknowledged': {'xams-daq_reader_0': 0}}

# %%
import datetime

# %%
active_doc = dbn['detector_control_new'].insert_one({
    "detector" : 'xams',
    "key": 'active',
    "field": 'active',
    "value": 'false',
    "user": 'dipede',
    "time": datetime.datetime.now(),   
})

# %%
mode_doc = dbn['detector_control_new'].insert_one({
    "detector" : 'xams',
    "key": 'mode',
    "field": 'mode',
    "value": 'document_V1730_software_update',
    "user": 'dipede',
    "time": datetime.datetime.now(),   
})

comment_doc = dbn['detector_control_new'].insert_one({
    "detector" : 'xams',
    "key": 'comment',
    "field": 'comment',
    "value": 'Do you see this comment? Awesome, good job!',
    "user": 'dipede',
    "time": datetime.datetime.now(),   
})

softstop_doc = dbn['detector_control_new'].insert_one({
    "detector" : 'xams',
    "key": 'softstop',
    "field": 'softstop',
    "value": '30',
    "user": 'dipede',
    "time": datetime.datetime.now(),   
})

stop_after_doc = dbn['detector_control_new'].insert_one({
    "detector" : 'xams',
    "key": 'stop_after',
    "field": 'stop_after',
    "value": '30',
    "user": 'dipede',
    "time": datetime.datetime.now(),   
})

# %%
doc=dbn['detector_control_new'].find_one({"value":"document_V1730_software_update"})
doc
# Out:
# {'_id': ObjectId('6166ac182a3b24a32404a8cd'),
#  'detector': 'xams',
#  'key': 'xams.mode',
#  'field': 'mode',
#  'value': 'document_V1730_software_update',
#  'user': 'dipede',
#  'time': 'datetime.now()'}

# %%
doc = dbn['options'].find_one({'name':"document_V1730_software_update"})
doc
# Out:
# {'_id': ObjectId('616689a53b793edfdd35780b'),
#  'user': 'sdipede',
#  'name': 'document_V1730_software_update',
#  'description': 'Document to update redax',
#  'detector': 'xams',
#  'run_start': 0,
#  'compressor': 'lz4',
#  'processing_threads': {'xams-daq_reader_0': 1},
#  'firmware_version': 0,
#  'baseline_dac_mode': 'fixed',
#  'baseline_value': 16000,
#  'baseline_fixed_value': 4000,
#  'detectors': {'xams-daq_reader_0': 'xams'},
#  'baseline_max_iterations': 2,
#  'baseline_max_steps': 30,
#  'baseline_adjustment_threshold': 10,
#  'baseline_convergence_threshold': 3,
#  'baseline_min_adjustment': 10,
#  'baseline_rebin_log2': 2,
#  'baseline_bins_around_max': 4,
#  'baseline_fraction_around_max': 0.5,
#  'baseline_triggers_per_step': 3,
#  'baseline_ms_between_triggers': 10,
#  'blt_safety_factor': 1.5,
#  'buffer_safety_factor': 1.1,
#  'buffer_type': 'dual',
#  'do_sn_check': 1,
#  'boards': [{'crate': 0,
#    'link': 0,
#    'board': 77,
#    'vme_address': '0',
#    'type': 'V1730',
#    'host': 'xams-daq_reader_0'}],
#  'registers': [{'reg': 'EF24',
#    'val': '1',
#    'board': 77,
#    'comment': 'Software reset'},
#   {'reg': 'EF1C',
#    'val': 'FF',
#    'board': 77,
#    'comment': 'Max number of events per blt'},
#   {'reg': 'EF00', 'val': '10', 'board': 77, 'comment': 'Readout control'},
#   {'reg': '8120', 'val': 'FF', 'board': 77, 'comment': 'Channel mask'},
#   {'reg': '8000', 'val': '310', 'board': 77, 'comment': 'Board configuration'},
#   {'reg': '8038',
#    'val': '19',
#    'board': 77,
#    'comment': 'Word in pretrigger window'},
#   {'reg': '8020',
#    'val': '32',
#    'board': 77,
#    'comment': 'Event size register. Required for new FW. Words.'},
#   {'reg': '8078',
#    'val': '19',
#    'board': 77,
#    'comment': 'Samples under threshold to close event.'},
#   {'reg': '8080',
#    'val': '510000',
#    'board': 77,
#    'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
#  'channels': {'77': [0, 1, 2, 3, 4, 5, 6, 7]},
#  'thresholds': {'77': [100, 100, 100, 100, 100, 100, 100, 100]},
#  'strax_chunk_overlap': 0.5,
#  'strax_output_path': '/home/xams/new_redax_data',
#  'strax_chunk_length': 5,
#  'strax_fragment_length': 220,
#  'strax_buffer_num_chunks': 3,
#  'strax_chunk_phase_limit': 2,
#  'strax_fragment_payload_bytes': 220}

# %% [markdown]
# Let's create another control collection.

# %%
dbn.create_collection('control_new')
# Out:
# Collection(Database(MongoClient(host=['127.0.0.1:27017'], document_class=dict, tz_aware=False, connect=True), 'daq'), 'control_new')

# %%
dbn.create_collection('status_new')
# Out:
# Collection(Database(MongoClient(host=['127.0.0.1:27017'], document_class=dict, tz_aware=False, connect=True), 'daq'), 'status_new')

# %%
dbn.create_collection('aggregate_status_new')
# Out:
# Collection(Database(MongoClient(host=['127.0.0.1:27017'], document_class=dict, tz_aware=False, connect=True), 'daq'), 'aggregate_status_new')

# %%
dbn.create_collection('log_new')
# Out:
# Collection(Database(MongoClient(host=['127.0.0.1:27017'], document_class=dict, tz_aware=False, connect=True), 'daq'), 'log_new')

# %%
doc_status = dbn['status'].find_one({'_id':'6167fcf3e44bea7dfd1bdca6'}) 
doc_status

# %%
import pymongo
import os
#from pymongo import MongoClient
#client = MongoClient("mongodb://user:password@127.0.0.1:27017/admin")
c = pymongo.MongoClient(f'mongodb://{os.environ["MONGO_USER"]}:{os.environ["MONGO_PASSWORD"]}@127.0.0.1:27017/admin')
c
# Out:
# MongoClient(host=['127.0.0.1:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
#dbn = client['daq']
dbn = c['daq']
rdbn = c['run']

# %%
doc = dbn['options'].find()
doc

# %%
doc = dbn['options'].find_one({"name":'document_V1730_software_update'})
doc
# Out:
# {'_id': ObjectId('616689a53b793edfdd35780b'),
#  'user': 'sdipede',
#  'name': 'document_V1730_software_update',
#  'description': 'Document to update redax',
#  'detector': 'xams',
#  'run_start': 0,
#  'compressor': 'lz4',
#  'processing_threads': {'xams-daq_reader_0': 1},
#  'firmware_version': 0,
#  'baseline_dac_mode': 'fixed',
#  'baseline_value': 16000,
#  'baseline_fixed_value': 4000,
#  'detectors': {'xams-daq_reader_0': 'xams'},
#  'baseline_max_iterations': 2,
#  'baseline_max_steps': 30,
#  'baseline_adjustment_threshold': 10,
#  'baseline_convergence_threshold': 3,
#  'baseline_min_adjustment': 10,
#  'baseline_rebin_log2': 2,
#  'baseline_bins_around_max': 4,
#  'baseline_fraction_around_max': 0.5,
#  'baseline_triggers_per_step': 3,
#  'baseline_ms_between_triggers': 10,
#  'blt_safety_factor': 1.5,
#  'buffer_safety_factor': 1.1,
#  'buffer_type': 'dual',
#  'do_sn_check': 1,
#  'boards': [{'crate': 0,
#    'link': 0,
#    'board': 77,
#    'vme_address': '0',
#    'type': 'V1730',
#    'host': 'xams-daq_reader_0'}],
#  'registers': [{'reg': 'EF24',
#    'val': '1',
#    'board': 77,
#    'comment': 'Software reset'},
#   {'reg': 'EF1C',
#    'val': 'FF',
#    'board': 77,
#    'comment': 'Max number of events per blt'},
#   {'reg': 'EF00', 'val': '10', 'board': 77, 'comment': 'Readout control'},
#   {'reg': '8120', 'val': 'FF', 'board': 77, 'comment': 'Channel mask'},
#   {'reg': '8000', 'val': '310', 'board': 77, 'comment': 'Board configuration'},
#   {'reg': '8038',
#    'val': '19',
#    'board': 77,
#    'comment': 'Word in pretrigger window'},
#   {'reg': '8020',
#    'val': '32',
#    'board': 77,
#    'comment': 'Event size register. Required for new FW. Words.'},
#   {'reg': '8078',
#    'val': '19',
#    'board': 77,
#    'comment': 'Samples under threshold to close event.'},
#   {'reg': '8080',
#    'val': '510000',
#    'board': 77,
#    'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
#  'channels': {'77': [0, 1, 2, 3, 4, 5, 6, 7]},
#  'thresholds': {'77': [100, 100, 100, 100, 100, 100, 100, 100]},
#  'strax_chunk_overlap': 0.5,
#  'strax_output_path': '/home/xams/new_redax_data',
#  'strax_chunk_length': 5,
#  'strax_fragment_length': 220,
#  'strax_buffer_num_chunks': 3,
#  'strax_chunk_phase_limit': 2,
#  'strax_fragment_payload_bytes': 220}

# %%
option_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':"sdipede", 
    'name':'try_baseline_fsroffset_v1730_temp',
    'description':'daq with V1730 with aaron',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
#     'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 16383,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 0,
                'link': 0,
               'board': 77,
               'vme_address': '0',
               'type': 'V1730',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 77,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 77, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 77, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 77, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 77,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 77,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 77,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 77,'comment': 'Samples under threshold to close event.'},
#                   {'reg': '8098', 'val': '7D0','board':77,'comment':'DC Offset for all the channels (hex)'},
#                   {'reg': '8060', 'val': '12', 'board': 77, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 77,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'77': [0, 1, 2,3,4,5,6,7]},
    'thresholds': {'77': [100, 100,100,100,100,100,100,100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
#     'strax_header_size': 31, # This is not really used 
    'strax_output_path': '/home/xams/xams_data_temp_Run2',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
new_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':'dipede', 
    'name':'try_baseline_maxdacoffset_v1724_temp',
    'description':'daq with V1724',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 65000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 1,
                'link': 0,
               'board': 770,
               'vme_address': '0',
               'type': 'V1724',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 770,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 770, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 770, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 770, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 770,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 770,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 770,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 770,'comment': 'Samples under threshold to close event.'},
#                   {'reg': '8060', 'val': '5B4', 'board': 770, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 770,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'770': [0, 1, 2, 3, 4, 5, 6, 7]},
    'thresholds': {'770': [100, 100, 100, 100, 100, 100, 100, 100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
#     'strax_header_size': 31,
    'strax_output_path': '/home/xams/xams_data_temp_Run2',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
new_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':'dipede', 
    'name':'try_baseline_maxdacoffset_v1724',
    'description':'daq with V1724',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 65000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 1,
                'link': 0,
               'board': 770,
               'vme_address': '0',
               'type': 'V1724',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 770,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 770, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 770, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 770, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 770,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 770,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 770,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 770,'comment': 'Samples under threshold to close event.'},
#                   {'reg': '8060', 'val': '5B4', 'board': 770, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 770,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'770': [0, 1, 2, 3, 4, 5, 6, 7]},
    'thresholds': {'770': [100, 100, 100, 100, 100, 100, 100, 100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
#     'strax_header_size': 31,
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
new_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':'dipede', 
    'name':'try_baseline_fsroffset_v1724',
    'description':'daq with V1724',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 16383,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 1,
                'link': 0,
               'board': 770,
               'vme_address': '0',
               'type': 'V1724',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 770,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 770, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 770, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 770, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 770,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 770,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 770,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 770,'comment': 'Samples under threshold to close event.'},
#                   {'reg': '8060', 'val': '5B4', 'board': 770, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 770,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'770': [0, 1, 2, 3, 4, 5, 6, 7]},
    'thresholds': {'770': [100, 100, 100, 100, 100, 100, 100, 100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
#     'strax_header_size': 31,
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
new_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':'dipede', 
    'name':'try_baseline_zerooffset_v1724',
    'description':'daq with V1724',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 0,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 1,
                'link': 0,
               'board': 770,
               'vme_address': '0',
               'type': 'V1724',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 770,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 770, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 770, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 770, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 770,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 770,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 770,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 770,'comment': 'Samples under threshold to close event.'},
#                   {'reg': '8060', 'val': '5B4', 'board': 770, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 770,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'770': [0, 1, 2, 3, 4, 5, 6, 7]},
    'thresholds': {'770': [100, 100, 100, 100, 100, 100, 100, 100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
#     'strax_header_size': 31,
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
new_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':'dipede', 
    'name':'try_baseline_fit_v1724',
    'description':'daq with V1724',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fit',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 4000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 1,
                'link': 0,
               'board': 770,
               'vme_address': '0',
               'type': 'V1724',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 770,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 770, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 770, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 770, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 770,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 770,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 770,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 770,'comment': 'Samples under threshold to close event.'},
#                   {'reg': '8060', 'val': '5B4', 'board': 770, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 770,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'770': [0, 1, 2, 3, 4, 5, 6, 7]},
    'thresholds': {'770': [100, 100, 100, 100, 100, 100, 100, 100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
#     'strax_header_size': 31,
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
new_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':'dipede', 
    'name':'try_baseline_offset_v1724',
    'description':'daq with V1724',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 4000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 1,
                'link': 0,
               'board': 770,
               'vme_address': '0',
               'type': 'V1724',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 770,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 770, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 770, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 770, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 770,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 770,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 770,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 770,'comment': 'Samples under threshold to close event.'},
#                   {'reg': '8060', 'val': '5B4', 'board': 770, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 770,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'770': [0, 1, 2, 3, 4, 5, 6, 7]},
    'thresholds': {'770': [100, 100, 100, 100, 100, 100, 100, 100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
#     'strax_header_size': 31,
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
option_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':"sdipede", 
    'name':'try_fitbaseline_part3',
    'description':'daq with V1730 with aaron',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fit',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 4000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_fallback_mode':'fixed',
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 400,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 0,
                'link': 0,
               'board': 77,
               'vme_address': '0',
               'type': 'V1730',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 77,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 77, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 77, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 77, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 77,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 77,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 77,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 77,'comment': 'Samples under threshold to close event.'},
#                   {'reg': '8098', 'val': 'FDE8','board':77,'comment':'DC Offset for all the channels (hex)'},
#                   {'reg': '8060', 'val': '12', 'board': 77, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 77,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'77': [0, 1, 2,3,4,5,6,7]},
    'thresholds': {'77': [100, 100,100,100,100,100,100,100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
#     'strax_header_size': 31, # This is not really used 
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
option_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':"sdipede", 
    'name':'try_fitbaseline_part2',
    'description':'daq with V1730 with aaron',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fit',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 4000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_fallback_mode':'fixed',
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 0,
                'link': 0,
               'board': 77,
               'vme_address': '0',
               'type': 'V1730',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 77,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 77, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 77, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 77, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 77,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 77,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 77,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 77,'comment': 'Samples under threshold to close event.'},
#                   {'reg': '8098', 'val': 'FDE8','board':77,'comment':'DC Offset for all the channels (hex)'},
#                   {'reg': '8060', 'val': '12', 'board': 77, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 77,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'77': [0, 1, 2,3,4,5,6,7]},
    'thresholds': {'77': [100, 100,100,100,100,100,100,100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
#     'strax_header_size': 31, # This is not really used 
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
option_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':"sdipede", 
    'name':'try_fitbaseline',
    'description':'daq with V1730 with aaron',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fit',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
#     'baseline_fixed_value': 16000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 0,
                'link': 0,
               'board': 77,
               'vme_address': '0',
               'type': 'V1730',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 77,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 77, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 77, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 77, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 77,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 77,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 77,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 77,'comment': 'Samples under threshold to close event.'},
#                   {'reg': '8098', 'val': 'FDE8','board':77,'comment':'DC Offset for all the channels (hex)'},
#                   {'reg': '8060', 'val': '12', 'board': 77, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 77,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'77': [0, 1, 2,3,4,5,6,7]},
    'thresholds': {'77': [100, 100,100,100,100,100,100,100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
#     'strax_header_size': 31, # This is not really used 
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
option_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':"sdipede", 
    'name':'try_change_register_part2',
    'description':'daq with V1730 with aaron',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
#     'baseline_dac_mode': 'fixed',
#     'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
#     'baseline_fixed_value': 16000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 0,
                'link': 0,
               'board': 77,
               'vme_address': '0',
               'type': 'V1730',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 77,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 77, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 77, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 77, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 77,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 77,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 77,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 77,'comment': 'Samples under threshold to close event.'},
                  {'reg': '8098', 'val': 'FDE8','board':77,'comment':'DC Offset for all the channels (hex)'},
#                   {'reg': '8060', 'val': '12', 'board': 77, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 77,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'77': [0, 1, 2,3,4,5,6,7]},
    'thresholds': {'77': [100, 100,100,100,100,100,100,100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
#     'strax_header_size': 31, # This is not really used 
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
option_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':"sdipede", 
    'name':'try_change_register_part1',
    'description':'daq with V1730 with aaron',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
#     'baseline_dac_mode': 'fixed',
#     'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
#     'baseline_fixed_value': 16000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 0,
                'link': 0,
               'board': 77,
               'vme_address': '0',
               'type': 'V1730',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 77,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 77, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 77, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 77, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 77,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 77,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 77,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 77,'comment': 'Samples under threshold to close event.'},
                  {'reg': '8098', 'val': '0','board':77,'comment':'DC Offset for all the channels (hex)'},
#                   {'reg': '8060', 'val': '12', 'board': 77, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 77,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'77': [0, 1, 2,3,4,5,6,7]},
    'thresholds': {'77': [100, 100,100,100,100,100,100,100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
#     'strax_header_size': 31, # This is not really used 
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
option_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':"sdipede", 
    'name':'try_calculation_aaron_upper',
    'description':'daq with V1730 with aaron',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
#     'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 16000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 0,
                'link': 0,
               'board': 77,
               'vme_address': '0',
               'type': 'V1730',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 77,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 77, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 77, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 77, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 77,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 77,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 77,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 77,'comment': 'Samples under threshold to close event.'},
#                   {'reg': '8098', 'val': '7D0','board':77,'comment':'DC Offset for all the channels (hex)'},
#                   {'reg': '8060', 'val': '12', 'board': 77, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 77,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'77': [0, 1, 2,3,4,5,6,7]},
    'thresholds': {'77': [100, 100,100,100,100,100,100,100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
#     'strax_header_size': 31, # This is not really used 
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
option_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':"sdipede", 
    'name':'try_calculation_aaron',
    'description':'daq with V1730 with aaron',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
#     'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 32767,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 0,
                'link': 0,
               'board': 77,
               'vme_address': '0',
               'type': 'V1730',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 77,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 77, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 77, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 77, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 77,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 77,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 77,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 77,'comment': 'Samples under threshold to close event.'},
#                   {'reg': '8098', 'val': '7D0','board':77,'comment':'DC Offset for all the channels (hex)'},
#                   {'reg': '8060', 'val': '12', 'board': 77, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 77,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'77': [0, 1, 2,3,4,5,6,7]},
    'thresholds': {'77': [100, 100,100,100,100,100,100,100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
#     'strax_header_size': 31, # This is not really used 
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
option_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':"sdipede", 
    'name':'try_calculation',
    'description':'daq with V1730 with aaron',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
#     'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 32000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 0,
                'link': 0,
               'board': 77,
               'vme_address': '0',
               'type': 'V1730',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 77,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 77, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 77, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 77, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 77,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 77,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 77,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 77,'comment': 'Samples under threshold to close event.'},
#                   {'reg': '8098', 'val': '7D0','board':77,'comment':'DC Offset for all the channels (hex)'},
#                   {'reg': '8060', 'val': '12', 'board': 77, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 77,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'77': [0, 1, 2,3,4,5,6,7]},
    'thresholds': {'77': [100, 100,100,100,100,100,100,100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
#     'strax_header_size': 31, # This is not really used 
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
option_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':"sdipede", 
    'name':'try_aaron_calculation',
    'description':'daq with V1730 with aaron',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
#     'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 32000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 0,
                'link': 0,
               'board': 77,
               'vme_address': '0',
               'type': 'V1730',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 77,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 77, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 77, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 77, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 77,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 77,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 77,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 77,'comment': 'Samples under threshold to close event.'},
#                   {'reg': '8098', 'val': '7D0','board':77,'comment':'DC Offset for all the channels (hex)'},
#                   {'reg': '8060', 'val': '12', 'board': 77, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 77,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'77': [0, 1]},
    'thresholds': {'77': [100, 100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
#     'strax_header_size': 31, # This is not really used 
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
option_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':"sdipede", 
    'name':'try_baseline_2nd',
    'description':'daq with V1730, baseline tries',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
#     'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 16000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 0,
                'link': 0,
               'board': 77,
               'vme_address': '0',
               'type': 'V1730',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 77,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 77, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 77, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 77, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 77,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 77,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 77,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 77,'comment': 'Samples under threshold to close event.'},
#                   {'reg': '8060', 'val': '12', 'board': 77, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 77,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'77': [0, 1, 2, 3, 4, 5, 6, 7]},
    'thresholds': {'77': [100, 100, 100, 100, 100, 100, 100, 100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
    'strax_header_size': 31,
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
option_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':"sdipede", 
    'name':'try_baseline_2nd',
    'description':'daq with V1730, baseline tries',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
#     'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 16000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 0,
                'link': 0,
               'board': 77,
               'vme_address': '0',
               'type': 'V1730',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 77,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 77, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 77, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 77, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 77,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 77,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 77,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 77,'comment': 'Samples under threshold to close event.'},
#                   {'reg': '8060', 'val': '12', 'board': 77, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 77,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'77': [0, 1, 2, 3, 4, 5, 6, 7]},
    'thresholds': {'77': [100, 100, 100, 100, 100, 100, 100, 100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
    'strax_header_size': 31,
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
option_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':"sdipede", 
    'name':'try_baseline_max',
    'description':'daq with V1730, baseline 16000',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 16000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 0,
                'link': 0,
               'board': 77,
               'vme_address': '0',
               'type': 'V1730',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 77,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 77, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 77, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 77, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 77,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 77,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 77,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 77,'comment': 'Samples under threshold to close event.'},
#                   {'reg': '8060', 'val': '12', 'board': 77, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 77,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'77': [0, 1, 2, 3, 4, 5, 6, 7]},
    'thresholds': {'77': [100, 100, 100, 100, 100, 100, 100, 100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
    'strax_header_size': 31,
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
option_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':"sdipede", 
    'name':'xamsl_run0_V1730_maxbsl',
    'description':'daq with V1730, 16000 bsl',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 16000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 0,
                'link': 0,
               'board': 77,
               'vme_address': '0',
               'type': 'V1730',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 77,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 77, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 77, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 77, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 77,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 77,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 77,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 77,'comment': 'Samples under threshold to close event.'},
#                   {'reg': '8060', 'val': '12', 'board': 77, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 77,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'77': [0, 1, 2, 3, 4, 5, 6, 7]},
    'thresholds': {'77': [100, 100, 100, 100, 100, 100, 100, 100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
    'strax_header_size': 31,
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
option_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':"sdipede", 
    'name':'xamsl_run0_V1730_zerobsl',
    'description':'daq with V1730, zero bsl',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
    'baseline_value': 0, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 0,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 0,
                'link': 0,
               'board': 77,
               'vme_address': '0',
               'type': 'V1730',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 77,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 77, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 77, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 77, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 77,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 77,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 77,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 77,'comment': 'Samples under threshold to close event.'},
#                   {'reg': '8060', 'val': '12', 'board': 77, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 77,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'77': [0, 1, 2, 3, 4, 5, 6, 7]},
    'thresholds': {'77': [100, 100, 100, 100, 100, 100, 100, 100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
    'strax_header_size': 31,
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
option_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':"sdipede", 
    'name':'xamsl_run0_V1730_200mV',
    'description':'daq with V1730, 200mV threshold',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 4000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 0,
                'link': 0,
               'board': 77,
               'vme_address': '0',
               'type': 'V1730',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 77,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 77, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 77, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 77, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 77,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 77,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 77,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 77,'comment': 'Samples under threshold to close event.'},
#                   {'reg': '8060', 'val': '12', 'board': 77, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 77,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'77': [0, 1, 2, 3, 4, 5, 6, 7]},
    'thresholds': {'77': [1640, 1640, 1640, 1640, 1640, 1640, 1640, 1640]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
    'strax_header_size': 31,
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
option_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':"sdipede", 
    'name':'xamsl_run0_V1730_12mV',
    'description':'daq with V1730, 12.2mV threshold',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 4000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 0,
                'link': 0,
               'board': 77,
               'vme_address': '0',
               'type': 'V1730',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 77,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 77, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 77, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 77, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 77,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 77,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 77,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 77,'comment': 'Samples under threshold to close event.'},
#                   {'reg': '8060', 'val': '12', 'board': 77, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 77,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'77': [0, 1, 2, 3, 4, 5, 6, 7]},
    'thresholds': {'77': [100, 100, 100, 100, 100, 100, 100, 100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
    'strax_header_size': 31,
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
option_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':"sdipede", 
    'name':'xamsl_run2_V1730_12mV',
    'description':'daq with V1730, 12.2mV threshold',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 4000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 0,
                'link': 0,
               'board': 77,
               'vme_address': '0',
               'type': 'V1730',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 77,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 77, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 77, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 77, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 77,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 77,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 77,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 77,'comment': 'Samples under threshold to close event.'},
#                   {'reg': '8060', 'val': '12', 'board': 77, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 77,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'77': [8, 9, 10, 11, 12, 13, 14, 15]},
    'thresholds': {'77': [100, 100, 100, 100, 100, 100, 100, 100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
    'strax_header_size': 31,
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
new_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':'dipede', 
    'name':'Run0_V1724_xamsl_chth_550mV',
    'description':'Run XAMSL with V1724, increase the per-channel threshold',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 4000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 1,
                'link': 0,
               'board': 770,
               'vme_address': '0',
               'type': 'V1724',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 770,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 770, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 770, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 770, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 770,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 770,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 770,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 770,'comment': 'Samples under threshold to close event.'},
#                   {'reg': '8060', 'val': 'E42', 'board': 770, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 770,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'770': [0, 1, 2, 3, 4, 5, 6, 7]},
    'thresholds': {'770': [4010, 4010, 4010, 4010, 4010, 4010, 4010, 4010]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
    'strax_header_size': 31,
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
new_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':'dipede', 
    'name':'Run0_V1724_xamsl_chth_500mV',
    'description':'Run XAMSL with V1724, increase the per-channel threshold',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 4000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 1,
                'link': 0,
               'board': 770,
               'vme_address': '0',
               'type': 'V1724',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 770,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 770, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 770, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 770, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 770,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 770,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 770,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 770,'comment': 'Samples under threshold to close event.'},
#                   {'reg': '8060', 'val': 'E42', 'board': 770, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 770,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'770': [0, 1, 2, 3, 4, 5, 6, 7]},
    'thresholds': {'770': [3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
    'strax_header_size': 31,
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
new_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':'dipede', 
    'name':'Run2_xamsl_V1724_tempWriting',
    'description':'Run 2 XAMSL with V1724, temporary writing to xams pc',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 4000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 1,
                'link': 0,
               'board': 770,
               'vme_address': '0',
               'type': 'V1724',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 770,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 770, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 770, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 770, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 770,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 770,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 770,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 770,'comment': 'Samples under threshold to close event.'},
                  {'reg': '8060', 'val': '12', 'board': 770, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 770,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'770': [0, 1, 2, 3, 4, 5, 6, 7]},
    'thresholds': {'770': [100, 100, 100, 100, 100, 100, 100, 100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
    'strax_header_size': 31,
    'strax_output_path': '/home/xams/xams_data_temp_Run2',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
new_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':'dipede', 
    'name':'Run2_xamsl_V1724_200mV_tempWriting',
    'description':'Run 2 XAMSL with V1724_200mV, temporary writing to xams pc',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 4000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 1,
                'link': 0,
               'board': 770,
               'vme_address': '0',
               'type': 'V1724',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 770,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 770, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 770, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 770, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 770,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 770,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 770,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 770,'comment': 'Samples under threshold to close event.'},
                  {'reg': '8060', 'val': '5B4', 'board': 770, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 770,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'770': [0, 1, 2, 3, 4, 5, 6, 7]},
    'thresholds': {'770': [100, 100, 100, 100, 100, 100, 100, 100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
    'strax_header_size': 31,
    'strax_output_path': '/home/xams/xams_data_temp_Run2',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
new_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':'dipede', 
    'name':'Run0_V1724_xamsl_digith200mV_chth100mV',
    'description':'Run XAMSL with V1724, increase the digi and ch thresholds',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 4000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 1,
                'link': 0,
               'board': 770,
               'vme_address': '0',
               'type': 'V1724',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 770,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 770, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 770, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 770, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 770,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 770,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 770,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 770,'comment': 'Samples under threshold to close event.'},
                  {'reg': '8060', 'val': '5B4', 'board': 770, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 770,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'770': [0, 1, 2, 3, 4, 5, 6, 7]},
    'thresholds': {'770': ['2DA', '2DA', '2DA', '2DA', '2DA', '2DA', '2DA', '2DA']},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
    'strax_header_size': 31,
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
new_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':'dipede', 
    'name':'Run0_V1724_xamsl_digith_50mV',
    'description':'Run XAMSL with V1724, increase the digi threshold',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 4000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 1,
                'link': 0,
               'board': 770,
               'vme_address': '0',
               'type': 'V1724',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 770,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 770, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 770, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 770, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 770,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 770,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 770,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 770,'comment': 'Samples under threshold to close event.'},
                  {'reg': '8060', 'val': '16D', 'board': 770, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 770,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'770': [0, 1, 2, 3, 4, 5, 6, 7]},
    'thresholds': {'770': [100, 100, 100, 100, 100, 100, 100, 100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
    'strax_header_size': 31,
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
new_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':'dipede', 
    'name':'Run0_V1724_xamsl_digith_100mV',
    'description':'Run XAMSL with V1724, increase the digi threshold',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 4000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 1,
                'link': 0,
               'board': 770,
               'vme_address': '0',
               'type': 'V1724',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 770,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 770, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 770, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 770, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 770,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 770,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 770,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 770,'comment': 'Samples under threshold to close event.'},
                  {'reg': '8060', 'val': '2DA', 'board': 770, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 770,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'770': [0, 1, 2, 3, 4, 5, 6, 7]},
    'thresholds': {'770': [100, 100, 100, 100, 100, 100, 100, 100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
    'strax_header_size': 31,
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
new_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':'dipede', 
    'name':'Run0_V1724_xamsl_digith_200mV',
    'description':'Run XAMSL with V1724, increase the digi threshold',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 4000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 1,
                'link': 0,
               'board': 770,
               'vme_address': '0',
               'type': 'V1724',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 770,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 770, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 770, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 770, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 770,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 770,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 770,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 770,'comment': 'Samples under threshold to close event.'},
                  {'reg': '8060', 'val': '5B4', 'board': 770, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 770,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'770': [0, 1, 2, 3, 4, 5, 6, 7]},
    'thresholds': {'770': [100, 100, 100, 100, 100, 100, 100, 100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
    'strax_header_size': 31,
    'strax_output_path': '/data/xenon/xams/run11',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
new_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':'dipede', 
    'name':'Run0_V1724_xamsl_run12',
    'description':'Run XAMSL with V1724',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 4000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 1,
                'link': 0,
               'board': 770,
               'vme_address': '0',
               'type': 'V1724',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 770,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 770, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 770, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 770, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 770,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 770,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 770,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 770,'comment': 'Samples under threshold to close event.'},
                  {'reg': '8060', 'val': '12', 'board': 770, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 770,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'770': [0, 1, 2, 3, 4, 5, 6, 7]},
    'thresholds': {'770': [100, 100, 100, 100, 100, 100, 100, 100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
    'strax_header_size': 31,
    'strax_output_path': '/data/xenon/xams/run12',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
new_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':'dipede', 
    'name':'Run0_V1724_xamsl_run12',
    'description':'Run XAMSL with V1724',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 4000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 1,
                'link': 0,
               'board': 770,
               'vme_address': '0',
               'type': 'V1724',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 770,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 770, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 770, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 770, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 770,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 770,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 770,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 770,'comment': 'Samples under threshold to close event.'},
                  {'reg': '8060', 'val': '12', 'board': 770, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 770,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'770': [0, 1, 2, 3, 4, 5, 6, 7]},
    'thresholds': {'770': [100, 100, 100, 100, 100, 100, 100, 100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
    'strax_header_size': 31,
    'strax_output_path': '/data/xenon/xams/run12',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
doc2 = dbn['options'].find_one({"name":'Run0_V1724_xamsl_run12'})
doc2
# Out:
# {'_id': ObjectId('614098e28e9e82290298beb2'),
#  'user': 'dipede',
#  'name': 'Run0_V1724_xamsl_run12',
#  'description': 'Run XAMSL with V1724',
#  'detector': 'xams',
#  'run_start': 0,
#  'compressor': 'lz4',
#  'processing_threads': {'xams-daq_reader_0': 1},
#  'firmware_version': 0,
#  'baseline_dac_mode': 'fixed',
#  'baseline_value': 16000,
#  'baseline_fixed_value': 4000,
#  'detectors': {'xams-daq_reader_0': 'xams'},
#  'baseline_max_iterations': 2,
#  'baseline_max_steps': 30,
#  'baseline_adjustment_threshold': 10,
#  'baseline_convergence_threshold': 3,
#  'baseline_min_adjustment': 10,
#  'baseline_rebin_log2': 2,
#  'baseline_bins_around_max': 4,
#  'baseline_fraction_around_max': 0.5,
#  'baseline_triggers_per_step': 3,
#  'baseline_ms_between_triggers': 10,
#  'blt_safety_factor': 1.5,
#  'buffer_safety_factor': 1.1,
#  'buffer_type': 'dual',
#  'do_sn_check': 1,
#  'boards': [{'crate': 1,
#    'link': 0,
#    'board': 770,
#    'vme_address': '0',
#    'type': 'V1724',
#    'host': 'xams-daq_reader_0'}],
#  'registers': [{'reg': 'EF24',
#    'val': '1',
#    'board': 770,
#    'comment': 'Software reset'},
#   {'reg': 'EF1C',
#    'val': 'FF',
#    'board': 770,
#    'comment': 'Max number of events per blt'},
#   {'reg': 'EF00', 'val': '10', 'board': 770, 'comment': 'Readout control'},
#   {'reg': '8120', 'val': 'FF', 'board': 770, 'comment': 'Channel mask'},
#   {'reg': '8000',
#    'val': '310',
#    'board': 770,
#    'comment': 'Board configuration'},
#   {'reg': '8038',
#    'val': '19',
#    'board': 770,
#    'comment': 'Word in pretrigger window'},
#   {'reg': '8020',
#    'val': '32',
#    'board': 770,
#    'comment': 'Event size register. Required for new FW. Words.'},
#   {'reg': '8078',
#    'val': '19',
#    'board': 770,
#    'comment': 'Samples under threshold to close event.'},
#   {'reg': '8060', 'val': '12', 'board': 770, 'comment': 'Trigger threshold. '},
#   {'reg': '8080',
#    'val': '510000',
#    'board': 770,
#    'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
#  'channels': {'770': [0, 1, 2, 3, 4, 5, 6, 7]},
#  'thresholds': {'770': [100, 100, 100, 100, 100, 100, 100, 100]},
#  'strax_chunk_overlap': 0.5,
#  'strax_header_size': 31,
#  'strax_output_path': '/data/xenon/xams/run12',
#  'strax_chunk_length': 5,
#  'strax_fragment_length': 220,
#  'strax_buffer_num_chunks': 3,
#  'strax_chunk_phase_limit': 2,
#  'strax_fragment_payload_bytes': 220}

# %% [markdown]
# To delete all the documents in a collection

# %%
collection_name.delete_many({ })

# %%
# Options document to have data from one digitizer V1724

option_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':"serena", 
    'name':'try0_V1724_redax2.0',
    'description':'Run with the V1724',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 4000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 1,
                'link': 0,
               'board': 770,
               'vme_address': '0',
               'type': 'V1724',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 770,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 770, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 770, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 770, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 770,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 770,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 770,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 770,'comment': 'Samples under threshold to close event.'},
                  {'reg': '8060', 'val': '12', 'board': 770, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 770,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'770': [0, 1, 2, 3, 4, 5, 6, 7]},
    'thresholds': {'770': [100, 100, 100, 100, 100, 100, 100, 100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
    'strax_header_size': 31,
    'strax_output_path': '/home/xams/daq/redax/data',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
dbn['detector_control'].insert_one({ "time" : "datetime.now()",
                                        "detector" : "xams", 
                                        "active" : "false",
                                        "stop_after" : "60", #How many minutes until the run automatically restarts
                                        "mode" : "try0_V1724_redax2.0",
                                        "user" : "Serena",
                                        "comment" : "11/2020",
                                        "link_mv" : "false",
                                        "link_nv" : "false",
                                        "remote": "false"
})

# %% [markdown]
# To update an field into a collection:

# %%
doc['strax_output_path'] = '/data/xenon/xams/data'
dbn['options'].update_one({"name":"Run0_V1724"}, {"$set":doc})
newdoc =  dbn['options'].find_one({"name":"Run0_V1724"})

# %% [markdown]
# From 17/3/2021

# %%
# option_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':"sdipede", 
    'name':'Run0_V1724',
    'description':'Run with the V1724',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 4000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 1,
                'link': 0,
               'board': 770,
               'vme_address': '0',
               'type': 'V1724',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 770,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 770, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 770, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 770, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 770,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 770,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 770,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 770,'comment': 'Samples under threshold to close event.'},
                  {'reg': '8060', 'val': '12', 'board': 770, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 770,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'770': [0, 1, 2, 3, 4, 5, 6, 7]},
    'thresholds': {'770': [100, 100, 100, 100, 100, 100, 100, 100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
    'strax_header_size': 31,
    'strax_output_path': '/home/xams/daq/redax/data',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})

# %%
option_doc = dbn['options'].insert_one({
#ORGANITATION FIELDS
    'user':"sdipede", 
    'name':'Run0_V1730',
    'description':'Run with the V1730',
    'detector':'xams', #to which detector this mode apply to
#SOFTWARE CONFIGURATION OPTIONS
#    "mongo_uri": , #set_mode_run
#    "mongo_database": "", #set_mode_run
#    "mongo_collection": "", #set_mode_run
    'run_start':0, #redax1.0, should I change this?
    'compressor': 'lz4',  #redax1.0, low level data compression
    'processing_threads': {'xams-daq_reader_0': 1}, #redax1.0, should I change this?
    'firmware_version': 0,#should I change this?
    'baseline_dac_mode': 'fixed',
    'baseline_value': 16000, #this is used in the case baseline_dac_mode = fit
    'baseline_fixed_value': 4000,
    'detectors': {'xams-daq_reader_0': 'xams'}, # Required argument
#LOW-LEVEL DIAGNOSTIC OPTIONS
    'baseline_max_iterations': 2,
    'baseline_max_steps': 30,
    'baseline_adjustment_threshold': 10,
    'baseline_convergence_threshold': 3,
    'baseline_min_adjustment': 10,
    'baseline_rebin_log2': 2,
    'baseline_bins_around_max': 4,
    'baseline_fraction_around_max': 0.5,
    'baseline_triggers_per_step': 3,
    'baseline_ms_between_triggers': 10,
#    'blt_size' : should we specify it?
    'blt_safety_factor': 1.5,
    'buffer_safety_factor': 1.1,
    'buffer_type': 'dual',
    'do_sn_check': 1,
#ELECTRONICS DEFINITION
    'boards' : [{'crate': 0,
                'link': 0,
               'board': 77,
               'vme_address': '0',
               'type': 'V1730',
               'host': 'xams-daq_reader_0'}],
    'registers': [{'reg': 'EF24', 'val': '1','board': 77,'comment': 'Software reset'},
                  {'reg': 'EF1C','val': 'FF','board': 77, 'comment': 'Max number of events per blt'},
                  {'reg': 'EF00', 'val': '10', 'board': 77, 'comment': 'Readout control'},
                  {'reg': '8120', 'val': 'FF', 'board': 77, 'comment': 'Channel mask'},
                  {'reg': '8000','val': '310','board': 77,'comment': 'Board configuration'},
                  {'reg': '8038','val': '19','board': 77,'comment': 'Word in pretrigger window'},
                  {'reg': '8020','val': '32','board': 77,'comment': 'Event size register. Required for new FW. Words.'},
                  {'reg': '8078','val': '19','board': 77,'comment': 'Samples under threshold to close event.'},
                  {'reg': '8060', 'val': '12', 'board': 77, 'comment': 'Trigger threshold. '},
                  {'reg': '8080','val': '510000','board': 77,'comment': 'DPP register. 310000 - DPP on, 256 sample baseline.'}],
    'channels':{'77': [8, 9, 10, 11, 12, 13, 14, 15]},
    'thresholds': {'77': [100, 100, 100, 100, 100, 100, 100, 100]},
#STRAX OUTPUT OPTIONS
    'strax_chunk_overlap': 0.5, # In redax1.0 was 0.4
    'strax_header_size': 31,
    'strax_output_path': '/data/xenon/xams/data',
    'strax_chunk_length': 5, #5.1 in redax1.0
    'strax_fragment_length': 220,
    'strax_buffer_num_chunks': 3,
    'strax_chunk_phase_limit': 2,
    'strax_fragment_payload_bytes': 220,
})
